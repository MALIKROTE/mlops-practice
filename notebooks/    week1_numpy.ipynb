# %%
import numpy as np

#declare numpy array
numbers = np.array([10,20,30,40,50])

numbers

type(numbers)

numbers.shape

print(numbers.mean())
print(numbers.max())
print(numbers.min())
print(numbers.sum())
# Out:
# 30.0
# 50
# 10
# 150

# %%
#2D Data (like ML data)

import numpy as np

data = np.array([
    [25, 2],
    [30, 5],
    [35, 8],
    [40, 10]
])

print(data)

print(data.shape)
# Out:
# [[25  2]
#  [30  5]
#  [35  8]
#  [40 10]]
# (4, 2)
